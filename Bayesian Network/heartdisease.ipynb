# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import pandas as pd

# %%
data = "http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data"

# %%
names = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "heartdisease"]
heartDisease = pd.read_csv(urlopen(data), names=names)

# %%
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %%
del heartDisease["ca"]
del heartDisease["slope"]
del heartDisease["thal"]
del heartDisease["oldpeak"]

# %%
heartDisease = heartDisease.replace("?", np.nan)
heartDisease.dtypes
# Out:
# age              int64
# sex              int64
# cp               int64
# trestbps        object
# chol            object
# fbs             object
# restecg         object
# thalach         object
# exang           object
# heartdisease     int64
# dtype: object

# %%
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

# %%
model = BayesianModel([("age", "trestbps"),
                       ("age", "fbs"),
                       ("sex", "trestbps"),
                       ("sex", "trestbps"),
                       ("exang", "trestbps"),
                       ("trestbps", "heartdisease"),
                       ("fbs", "heartdisease"),
                       ("heartdisease", "restecg"),
                       ("heartdisease", "thalach"),
                       ("heartdisease", "chol")])

# %%
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)

# %%
print(model.get_cpds("age"))
# Out:
# +---------+------------+
# | age(28) | 0.00383142 |
# +---------+------------+
# | age(29) | 0.00383142 |
# +---------+------------+
# | age(30) | 0.00383142 |
# +---------+------------+
# | age(31) | 0.00766284 |
# +---------+------------+
# | age(32) | 0.0153257  |
# +---------+------------+
# | age(33) | 0.00766284 |
# +---------+------------+
# | age(34) | 0.0153257  |
# +---------+------------+
# | age(35) | 0.0191571  |
# +---------+------------+
# | age(36) | 0.0191571  |
# +---------+------------+
# | age(37) | 0.0306513  |
# +---------+------------+
# | age(38) | 0.0191571  |
# +---------+------------+
# | age(39) | 0.0344828  |
# +---------+------------+
# | age(40) | 0.0191571  |
# +---------+------------+
# | age(41) | 0.0383142  |
# +---------+------------+
# | age(42) | 0.0268199  |
# +---------+------------+
# | age(43) | 0.0421456  |
# +---------+------------+
# | age(44) | 0.0268199  |
# +---------+------------+
# | age(45) | 0.0229885  |
# +---------+------------+
# | age(46) | 0.045977   |
# +---------+------------+
# | age(47) | 0.0344828  |
# +---------+------------+
# | age(48) | 0.0613027  |
# +---------+------------+
# | age(49) | 0.0421456  |
# +---------+------------+
# | age(50) | 0.045977   |
# +---------+------------+
# | age(51) | 0.0344828  |
# +---------+------------+
# | age(52) | 0.0574713  |
# +---------+------------+
# | age(53) | 0.0383142  |
# +---------+------------+
# | age(54) | 0.0842912  |
# +---------+------------+
# | age(55) | 0.0536398  |
# +---------+------------+
# | age(56) | 0.0306513  |
# +---------+------------+
# | age(57) | 0.0191571  |
# +---------+------------+
# | age(58) | 0.0344828  |
# +---------+------------+
# | age(59) | 0.0229885  |
# +---------+------------+
# | age(60) | 0.00766284 |
# +---------+------------+
# | age(61) | 0.00766284 |
# +---------+------------+
# | age(62) | 0.00766284 |
# +---------+------------+
# | age(63) | 0.00383142 |
# +---------+------------+
# | age(65) | 0.0114943  |
# +---------+------------+
# | age(66) | 0          |
# +---------+------------+

# %%
print(model.get_cpds("chol"))
# Out:
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(100)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(117)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(129)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(132)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(147)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(156)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(161)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(163)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(171)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(173)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(179)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(190)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(194)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(202)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.024539877300613498 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(238)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.012269938650306749 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(251)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.006134969325153374 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(272)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(279)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(280)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(285)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(287)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(291)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(292)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(297)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(312)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(320)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(328)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(329)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(331)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(336)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(338)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(339)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(344)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(347)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(355)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(358)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(365)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(388)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(392)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(393)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(404)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(412)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(466)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(468)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(491)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(518)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(529)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(603)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(85)     | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+

# %%
print(model.get_cpds("sex"))
# Out:
# +--------+----------+
# | sex(0) | 0.264368 |
# +--------+----------+
# | sex(1) | 0.735632 |
# +--------+----------+

# %%
model.get_independencies()
# Out:
# (age _|_ exang, sex)
# (age _|_ sex | exang)
# (age _|_ exang | sex)
# (age _|_ exang, sex | fbs)
# (age _|_ restecg, chol, thalach | heartdisease)
# (age _|_ chol, thalach | heartdisease, restecg)
# (age _|_ restecg, thalach | heartdisease, chol)
# (age _|_ sex | exang, fbs)
# (age _|_ restecg, chol, thalach | exang, heartdisease)
# (age _|_ heartdisease, restecg, chol, thalach | trestbps, fbs)
# (age _|_ restecg, chol, thalach | trestbps, heartdisease)
# (age _|_ restecg, chol | heartdisease, thalach)
# (age _|_ exang | sex, fbs)
# (age _|_ restecg, chol, thalach | heartdisease, sex)
# (age _|_ restecg, chol, thalach | heartdisease, fbs)
# (age _|_ thalach | heartdisease, restecg, chol)
# (age _|_ chol, thalach | exang, heartdisease, restecg)
# (age _|_ heartdisease, chol, thalach | trestbps, restecg, fbs)
# (age _|_ chol, thalach | heartdisease, trestbps, restecg)
# (age _|_ chol | heartdisease, restecg, thalach)
# (age _|_ chol, thalach | heartdisease, restecg, sex)
# (age _|_ chol, thalach | heartdisease, restecg, fbs)
# (age _|_ restecg, thalach | exang, heartdisease, chol)
# (age _|_ heartdisease, restecg, thalach | trestbps, chol, fbs)
# (age _|_ restecg, thalach | trestbps, heartdisease, chol)
# (age _|_ restecg | heartdisease, chol, thalach)
# (age _|_ restecg, thalach | sex, heartdisease, chol)
# (age _|_ restecg, thalach | heartdisease, chol, fbs)
# (age _|_ heartdisease, restecg, chol, thalach | exang, trestbps, fbs)
# (age _|_ restecg, chol, thalach | exang, trestbps, heartdisease)
# (age _|_ restecg, chol | exang, heartdisease, thalach)
# (age _|_ restecg, chol, thalach | exang, heartdisease, sex)
# (age _|_ restecg, chol, thalach | exang, heartdisease, fbs)
# (age _|_ heartdisease, restecg, chol | trestbps, fbs, thalach)
# (age _|_ restecg, chol | trestbps, heartdisease, thalach)
# (age _|_ heartdisease, restecg, chol, thalach | trestbps, sex, fbs)
# (age _|_ restecg, chol, thalach | trestbps, heartdisease, sex)
# (age _|_ restecg, chol, thalach | trestbps, heartdisease, fbs)
# (age _|_ restecg, chol | heartdisease, sex, thalach)
# (age _|_ restecg, chol | heartdisease, fbs, thalach)
# (age _|_ restecg, chol, thalach | heartdisease, sex, fbs)
# (age _|_ thalach | exang, heartdisease, restecg, chol)
# (age _|_ heartdisease, thalach | trestbps, restecg, chol, fbs)
# (age _|_ thalach | heartdisease, trestbps, restecg, chol)
# (age _|_ thalach | sex, restecg, chol, heartdisease)
# (age _|_ thalach | heartdisease, restecg, chol, fbs)
# (age _|_ heartdisease, chol, thalach | exang, trestbps, restecg, fbs)
# (age _|_ chol, thalach | exang, heartdisease, trestbps, restecg)
# (age _|_ chol | exang, heartdisease, restecg, thalach)
# (age _|_ chol, thalach | exang, heartdisease, restecg, sex)
# (age _|_ chol, thalach | exang, heartdisease, restecg, fbs)
# (age _|_ heartdisease, chol | trestbps, restecg, fbs, thalach)
# (age _|_ chol | heartdisease, trestbps, restecg, thalach)
# (age _|_ heartdisease, chol, thalach | trestbps, restecg, sex, fbs)
# (age _|_ chol, thalach | heartdisease, trestbps, restecg, sex)
# (age _|_ chol, thalach | heartdisease, trestbps, restecg, fbs)
# (age _|_ chol | heartdisease, restecg, sex, thalach)
# (age _|_ chol | heartdisease, restecg, fbs, thalach)
# (age _|_ chol, thalach | heartdisease, restecg, sex, fbs)
# (age _|_ restecg, heartdisease, thalach | exang, trestbps, chol, fbs)
# (age _|_ restecg, thalach | exang, trestbps, heartdisease, chol)
# (age _|_ restecg | exang, heartdisease, chol, thalach)
# (age _|_ restecg, thalach | exang, sex, heartdisease, chol)
# (age _|_ restecg, thalach | exang, heartdisease, chol, fbs)
# (age _|_ restecg, heartdisease | trestbps, chol, fbs, thalach)
# (age _|_ restecg | trestbps, heartdisease, chol, thalach)
# (age _|_ restecg, heartdisease, thalach | sex, trestbps, chol, fbs)
# (age _|_ restecg, thalach | sex, trestbps, heartdisease, chol)
# (age _|_ restecg, thalach | trestbps, heartdisease, chol, fbs)
# (age _|_ restecg | sex, heartdisease, chol, thalach)
# (age _|_ restecg | heartdisease, chol, fbs, thalach)
# (age _|_ restecg, thalach | sex, heartdisease, chol, fbs)
# (age _|_ heartdisease, restecg, chol | exang, trestbps, fbs, thalach)
# (age _|_ restecg, chol | exang, trestbps, heartdisease, thalach)
# (age _|_ restecg, heartdisease, chol, thalach | exang, trestbps, sex, fbs)
# (age _|_ restecg, chol, thalach | exang, trestbps, heartdisease, sex)
# (age _|_ restecg, chol, thalach | exang, trestbps, heartdisease, fbs)
# (age _|_ restecg, chol | exang, heartdisease, sex, thalach)
# (age _|_ restecg, chol | exang, heartdisease, fbs, thalach)
# (age _|_ restecg, chol, thalach | exang, heartdisease, sex, fbs)
# (age _|_ restecg, heartdisease, chol | trestbps, sex, fbs, thalach)
# (age _|_ restecg, chol | trestbps, heartdisease, sex, thalach)
# (age _|_ restecg, chol | trestbps, heartdisease, fbs, thalach)
# (age _|_ restecg, chol, thalach | trestbps, heartdisease, sex, fbs)
# (age _|_ restecg, chol | heartdisease, sex, fbs, thalach)
# (age _|_ heartdisease, thalach | restecg, chol, exang, trestbps, fbs)
# (age _|_ thalach | restecg, chol, exang, trestbps, heartdisease)
# (age _|_ thalach | restecg, chol, exang, sex, heartdisease)
# (age _|_ thalach | restecg, chol, exang, fbs, heartdisease)
# (age _|_ heartdisease | restecg, chol, trestbps, thalach, fbs)
# (age _|_ heartdisease, thalach | restecg, chol, trestbps, sex, fbs)
# (age _|_ thalach | restecg, chol, trestbps, sex, heartdisease)
# (age _|_ thalach | restecg, chol, trestbps, fbs, heartdisease)
# (age _|_ thalach | restecg, chol, sex, fbs, heartdisease)
# (age _|_ heartdisease, chol | restecg, exang, trestbps, thalach, fbs)
# (age _|_ chol | restecg, exang, trestbps, thalach, heartdisease)
# (age _|_ heartdisease, chol, thalach | restecg, exang, trestbps, sex, fbs)
# (age _|_ chol, thalach | restecg, exang, trestbps, sex, heartdisease)
# (age _|_ chol, thalach | restecg, exang, trestbps, fbs, heartdisease)
# (age _|_ chol | restecg, exang, thalach, sex, heartdisease)
# (age _|_ chol | restecg, exang, thalach, fbs, heartdisease)
# (age _|_ chol, thalach | restecg, exang, sex, fbs, heartdisease)
# (age _|_ heartdisease, chol | restecg, trestbps, thalach, sex, fbs)
# (age _|_ chol | restecg, trestbps, thalach, sex, heartdisease)
# (age _|_ chol | restecg, trestbps, thalach, fbs, heartdisease)
# (age _|_ chol, thalach | restecg, trestbps, sex, fbs, heartdisease)
# (age _|_ chol | restecg, thalach, sex, fbs, heartdisease)
# (age _|_ restecg, heartdisease | chol, exang, trestbps, thalach, fbs)
# (age _|_ restecg | chol, exang, trestbps, thalach, heartdisease)
# (age _|_ restecg, heartdisease, thalach | chol, exang, trestbps, sex, fbs)
# (age _|_ restecg, thalach | chol, exang, trestbps, sex, heartdisease)
# (age _|_ restecg, thalach | chol, exang, trestbps, fbs, heartdisease)
# (age _|_ restecg | chol, exang, thalach, sex, heartdisease)
# (age _|_ restecg | chol, exang, thalach, fbs, heartdisease)
# (age _|_ restecg, thalach | chol, exang, sex, fbs, heartdisease)
# (age _|_ restecg, heartdisease | chol, trestbps, thalach, sex, fbs)
# (age _|_ restecg | chol, trestbps, thalach, sex, heartdisease)
# (age _|_ restecg | chol, trestbps, thalach, fbs, heartdisease)
# (age _|_ restecg, thalach | chol, trestbps, sex, fbs, heartdisease)
# (age _|_ restecg | chol, thalach, sex, fbs, heartdisease)
# (age _|_ restecg, heartdisease, chol | exang, trestbps, thalach, sex, fbs)
# (age _|_ restecg, chol | exang, trestbps, thalach, sex, heartdisease)
# (age _|_ restecg, chol | exang, trestbps, thalach, fbs, heartdisease)
# (age _|_ restecg, chol, thalach | exang, trestbps, sex, fbs, heartdisease)
# (age _|_ restecg, chol | exang, thalach, sex, fbs, heartdisease)
# (age _|_ restecg, chol | trestbps, thalach, sex, fbs, heartdisease)
# (age _|_ heartdisease | restecg, chol, exang, trestbps, thalach, fbs)
# (age _|_ heartdisease, thalach | restecg, chol, exang, trestbps, sex, fbs)
# (age _|_ thalach | restecg, chol, exang, trestbps, sex, heartdisease)
# (age _|_ thalach | restecg, chol, exang, trestbps, fbs, heartdisease)
# (age _|_ thalach | restecg, chol, exang, sex, fbs, heartdisease)
# (age _|_ heartdisease | restecg, chol, trestbps, thalach, sex, fbs)
# (age _|_ thalach | restecg, chol, trestbps, sex, fbs, heartdisease)
# (age _|_ heartdisease, chol | restecg, exang, trestbps, thalach, sex, fbs)
# (age _|_ chol | restecg, exang, trestbps, thalach, sex, heartdisease)
# (age _|_ chol | restecg, exang, trestbps, thalach, fbs, heartdisease)
# (age _|_ chol, thalach | restecg, exang, trestbps, sex, fbs, heartdisease)
# (age _|_ chol | restecg, exang, thalach, sex, fbs, heartdisease)
# (age _|_ chol | restecg, trestbps, thalach, sex, fbs, heartdisease)
# (age _|_ restecg, heartdisease | chol, exang, trestbps, thalach, sex, fbs)
# (age _|_ restecg | chol, exang, trestbps, thalach, sex, heartdisease)
# (age _|_ restecg | chol, exang, trestbps, thalach, fbs, heartdisease)
# (age _|_ restecg, thalach | chol, exang, trestbps, sex, fbs, heartdisease)
# (age _|_ restecg | chol, exang, thalach, sex, fbs, heartdisease)
# (age _|_ restecg | chol, trestbps, thalach, sex, fbs, heartdisease)
# (age _|_ restecg, chol | exang, trestbps, thalach, sex, fbs, heartdisease)
# (age _|_ heartdisease | restecg, chol, exang, trestbps, thalach, sex, fbs)
# (age _|_ thalach | restecg, chol, exang, trestbps, sex, fbs, heartdisease)
# (age _|_ chol | restecg, exang, trestbps, thalach, sex, fbs, heartdisease)
# (age _|_ restecg | chol, exang, trestbps, thalach, sex, fbs, heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ restecg, chol, thalach | heartdisease)
# (trestbps _|_ chol, thalach | heartdisease, restecg)
# (trestbps _|_ restecg, thalach | heartdisease, chol)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ restecg, chol, thalach | age, heartdisease)
# (trestbps _|_ restecg, chol, thalach | exang, heartdisease)
# (trestbps _|_ restecg, chol | heartdisease, thalach)
# (trestbps _|_ restecg, chol, thalach | heartdisease, sex)
# (trestbps _|_ restecg, chol, thalach | heartdisease, fbs)
# (trestbps _|_ thalach | heartdisease, restecg, chol)
# (trestbps _|_ chol, thalach | age, heartdisease, restecg)
# (trestbps _|_ chol, thalach | exang, heartdisease, restecg)
# (trestbps _|_ chol | heartdisease, restecg, thalach)
# (trestbps _|_ chol, thalach | heartdisease, restecg, sex)
# (trestbps _|_ chol, thalach | heartdisease, restecg, fbs)
# (trestbps _|_ restecg, thalach | age, heartdisease, chol)
# (trestbps _|_ restecg, thalach | exang, heartdisease, chol)
# (trestbps _|_ restecg | heartdisease, chol, thalach)
# (trestbps _|_ restecg, thalach | sex, heartdisease, chol)
# (trestbps _|_ restecg, thalach | heartdisease, chol, fbs)
# (trestbps _|_ fbs | age, sex, exang)
# (trestbps _|_ restecg, chol, thalach | age, heartdisease, exang)
# (trestbps _|_ restecg, chol | age, heartdisease, thalach)
# (trestbps _|_ restecg, chol, thalach | age, heartdisease, sex)
# (trestbps _|_ restecg, chol, thalach | age, heartdisease, fbs)
# (trestbps _|_ restecg, chol | exang, heartdisease, thalach)
# (trestbps _|_ restecg, chol, thalach | exang, heartdisease, sex)
# (trestbps _|_ restecg, chol, thalach | exang, heartdisease, fbs)
# (trestbps _|_ restecg, chol | heartdisease, sex, thalach)
# (trestbps _|_ restecg, chol | heartdisease, fbs, thalach)
# (trestbps _|_ restecg, chol, thalach | heartdisease, sex, fbs)
# (trestbps _|_ thalach | age, heartdisease, restecg, chol)
# (trestbps _|_ thalach | exang, heartdisease, restecg, chol)
# (trestbps _|_ thalach | sex, restecg, chol, heartdisease)
# (trestbps _|_ thalach | heartdisease, restecg, chol, fbs)
# (trestbps _|_ chol, thalach | age, heartdisease, restecg, exang)
# (trestbps _|_ chol | age, heartdisease, restecg, thalach)
# (trestbps _|_ chol, thalach | age, heartdisease, restecg, sex)
# (trestbps _|_ chol, thalach | age, heartdisease, restecg, fbs)
# (trestbps _|_ chol | exang, heartdisease, restecg, thalach)
# (trestbps _|_ chol, thalach | exang, heartdisease, restecg, sex)
# (trestbps _|_ chol, thalach | exang, heartdisease, restecg, fbs)
# (trestbps _|_ chol | heartdisease, restecg, sex, thalach)
# (trestbps _|_ chol | heartdisease, restecg, fbs, thalach)
# (trestbps _|_ chol, thalach | heartdisease, restecg, sex, fbs)
# (trestbps _|_ restecg, thalach | age, exang, heartdisease, chol)
# (trestbps _|_ restecg | age, heartdisease, chol, thalach)
# (trestbps _|_ restecg, thalach | age, sex, heartdisease, chol)
# (trestbps _|_ restecg, thalach | age, heartdisease, chol, fbs)
# (trestbps _|_ restecg | exang, heartdisease, chol, thalach)
# (trestbps _|_ restecg, thalach | exang, sex, heartdisease, chol)
# (trestbps _|_ restecg, thalach | exang, heartdisease, chol, fbs)
# (trestbps _|_ restecg | sex, heartdisease, chol, thalach)
# (trestbps _|_ restecg | heartdisease, chol, fbs, thalach)
# (trestbps _|_ restecg, thalach | sex, heartdisease, chol, fbs)
# (trestbps _|_ restecg, chol | age, heartdisease, exang, thalach)
# (trestbps _|_ restecg, chol, thalach | age, sex, heartdisease, exang)
# (trestbps _|_ restecg, chol, thalach | age, heartdisease, exang, fbs)
# (trestbps _|_ restecg, chol | age, heartdisease, sex, thalach)
# (trestbps _|_ restecg, chol | age, heartdisease, fbs, thalach)
# (trestbps _|_ restecg, chol, thalach | age, heartdisease, sex, fbs)
# (trestbps _|_ restecg, chol | exang, heartdisease, sex, thalach)
# (trestbps _|_ restecg, chol | exang, heartdisease, fbs, thalach)
# (trestbps _|_ restecg, chol, thalach | exang, heartdisease, sex, fbs)
# (trestbps _|_ restecg, chol | heartdisease, sex, fbs, thalach)
# (trestbps _|_ thalach | restecg, chol, age, exang, heartdisease)
# (trestbps _|_ thalach | restecg, chol, age, sex, heartdisease)
# (trestbps _|_ thalach | restecg, chol, age, fbs, heartdisease)
# (trestbps _|_ thalach | restecg, chol, exang, sex, heartdisease)
# (trestbps _|_ thalach | restecg, chol, exang, fbs, heartdisease)
# (trestbps _|_ thalach | restecg, chol, sex, fbs, heartdisease)
# (trestbps _|_ chol | restecg, age, exang, thalach, heartdisease)
# (trestbps _|_ chol, thalach | restecg, age, exang, sex, heartdisease)
# (trestbps _|_ chol, thalach | restecg, age, exang, fbs, heartdisease)
# (trestbps _|_ chol | restecg, age, thalach, sex, heartdisease)
# (trestbps _|_ chol | restecg, age, thalach, fbs, heartdisease)
# (trestbps _|_ chol, thalach | restecg, age, sex, fbs, heartdisease)
# (trestbps _|_ chol | restecg, exang, thalach, sex, heartdisease)
# (trestbps _|_ chol | restecg, exang, thalach, fbs, heartdisease)
# (trestbps _|_ chol, thalach | restecg, exang, sex, fbs, heartdisease)
# (trestbps _|_ chol | restecg, thalach, sex, fbs, heartdisease)
# (trestbps _|_ restecg | chol, age, exang, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | chol, age, exang, sex, heartdisease)
# (trestbps _|_ restecg, thalach | chol, age, exang, fbs, heartdisease)
# (trestbps _|_ restecg | chol, age, thalach, sex, heartdisease)
# (trestbps _|_ restecg | chol, age, thalach, fbs, heartdisease)
# (trestbps _|_ restecg, thalach | chol, age, sex, fbs, heartdisease)
# (trestbps _|_ restecg | chol, exang, thalach, sex, heartdisease)
# (trestbps _|_ restecg | chol, exang, thalach, fbs, heartdisease)
# (trestbps _|_ restecg, thalach | chol, exang, sex, fbs, heartdisease)
# (trestbps _|_ restecg | chol, thalach, sex, fbs, heartdisease)
# (trestbps _|_ restecg, chol | age, exang, thalach, sex, heartdisease)
# (trestbps _|_ restecg, chol | age, exang, thalach, fbs, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, exang, sex, fbs, heartdisease)
# (trestbps _|_ restecg, chol | age, thalach, sex, fbs, heartdisease)
# (trestbps _|_ restecg, chol | exang, thalach, sex, fbs, heartdisease)
# (trestbps _|_ thalach | restecg, chol, age, exang, sex, heartdisease)
# (trestbps _|_ thalach | restecg, chol, age, exang, fbs, heartdisease)
# (trestbps _|_ thalach | restecg, chol, age, sex, fbs, heartdisease)
# (trestbps _|_ thalach | restecg, chol, exang, sex, fbs, heartdisease)
# (trestbps _|_ chol | restecg, age, exang, thalach, sex, heartdisease)
# (trestbps _|_ chol | restecg, age, exang, thalach, fbs, heartdisease)
# (trestbps _|_ chol, thalach | restecg, age, exang, sex, fbs, heartdisease)
# (trestbps _|_ chol | restecg, age, thalach, sex, fbs, heartdisease)
# (trestbps _|_ chol | restecg, exang, thalach, sex, fbs, heartdisease)
# (trestbps _|_ restecg | chol, age, exang, thalach, sex, heartdisease)
# (trestbps _|_ restecg | chol, age, exang, thalach, fbs, heartdisease)
# (trestbps _|_ restecg, thalach | chol, age, exang, sex, fbs, heartdisease)
# (trestbps _|_ restecg | chol, age, thalach, sex, fbs, heartdisease)
# (trestbps _|_ restecg | chol, exang, thalach, sex, fbs, heartdisease)
# (trestbps _|_ restecg, chol | age, exang, thalach, sex, fbs, heartdisease)
# (trestbps _|_ thalach | restecg, chol, age, exang, sex, fbs, heartdisease)
# (trestbps _|_ chol | restecg, age, exang, thalach, sex, fbs, heartdisease)
# (trestbps _|_ restecg | chol, age, exang, thalach, sex, fbs, heartdisease)
# (fbs _|_ exang, sex)
# (fbs _|_ exang, trestbps, sex | age)
# (fbs _|_ sex | exang)
# (fbs _|_ exang | sex)
# (fbs _|_ restecg, chol, thalach | heartdisease)
# (fbs _|_ chol, thalach | heartdisease, restecg)
# (fbs _|_ restecg, thalach | heartdisease, chol)
# (fbs _|_ trestbps, sex | age, exang)
# (fbs _|_ exang, sex | age, trestbps)
# (fbs _|_ exang, trestbps | age, sex)
# (fbs _|_ restecg, chol, thalach | age, heartdisease)
# (fbs _|_ restecg, chol, thalach | exang, heartdisease)
# (fbs _|_ restecg, chol, thalach | trestbps, heartdisease)
# (fbs _|_ restecg, chol | heartdisease, thalach)
# (fbs _|_ restecg, chol, thalach | heartdisease, sex)
# (fbs _|_ thalach | heartdisease, restecg, chol)
# (fbs _|_ exang, sex | age, trestbps, restecg)
# (fbs _|_ chol, thalach | age, heartdisease, restecg)
# (fbs _|_ chol, thalach | exang, heartdisease, restecg)
# (fbs _|_ chol, thalach | heartdisease, trestbps, restecg)
# (fbs _|_ chol | heartdisease, restecg, thalach)
# (fbs _|_ chol, thalach | heartdisease, restecg, sex)
# (fbs _|_ exang, sex | age, trestbps, chol)
# (fbs _|_ restecg, thalach | age, heartdisease, chol)
# (fbs _|_ restecg, thalach | exang, heartdisease, chol)
# (fbs _|_ restecg, thalach | trestbps, heartdisease, chol)
# (fbs _|_ restecg | heartdisease, chol, thalach)
# (fbs _|_ restecg, thalach | sex, heartdisease, chol)
# (fbs _|_ sex | age, trestbps, exang)
# (fbs _|_ trestbps | age, sex, exang)
# (fbs _|_ restecg, chol, thalach | age, heartdisease, exang)
# (fbs _|_ exang, sex | age, trestbps, thalach)
# (fbs _|_ exang | age, trestbps, sex)
# (fbs _|_ restecg, chol, sex, exang, thalach | age, trestbps, heartdisease)
# (fbs _|_ restecg, chol | age, heartdisease, thalach)
# (fbs _|_ restecg, chol, thalach | age, heartdisease, sex)
# (fbs _|_ restecg, chol, thalach | exang, trestbps, heartdisease)
# (fbs _|_ restecg, chol | exang, heartdisease, thalach)
# (fbs _|_ restecg, chol, thalach | exang, heartdisease, sex)
# (fbs _|_ restecg, chol | trestbps, heartdisease, thalach)
# (fbs _|_ restecg, chol, thalach | trestbps, heartdisease, sex)
# (fbs _|_ restecg, chol | heartdisease, sex, thalach)
# (fbs _|_ exang, sex | age, trestbps, restecg, chol)
# (fbs _|_ thalach | age, heartdisease, restecg, chol)
# (fbs _|_ thalach | exang, heartdisease, restecg, chol)
# (fbs _|_ thalach | heartdisease, trestbps, restecg, chol)
# (fbs _|_ thalach | sex, restecg, chol, heartdisease)
# (fbs _|_ sex | age, trestbps, restecg, exang)
# (fbs _|_ chol, thalach | age, heartdisease, restecg, exang)
# (fbs _|_ exang, sex | age, trestbps, restecg, thalach)
# (fbs _|_ exang | age, trestbps, restecg, sex)
# (fbs _|_ exang, chol, sex, thalach | age, heartdisease, trestbps, restecg)
# (fbs _|_ chol | age, heartdisease, restecg, thalach)
# (fbs _|_ chol, thalach | age, heartdisease, restecg, sex)
# (fbs _|_ chol, thalach | exang, heartdisease, trestbps, restecg)
# (fbs _|_ chol | exang, heartdisease, restecg, thalach)
# (fbs _|_ chol, thalach | exang, heartdisease, restecg, sex)
# (fbs _|_ chol | heartdisease, trestbps, restecg, thalach)
# (fbs _|_ chol, thalach | heartdisease, trestbps, restecg, sex)
# (fbs _|_ chol | heartdisease, restecg, sex, thalach)
# (fbs _|_ sex | age, exang, chol, trestbps)
# (fbs _|_ restecg, thalach | age, exang, heartdisease, chol)
# (fbs _|_ exang, sex | age, trestbps, chol, thalach)
# (fbs _|_ exang | age, sex, trestbps, chol)
# (fbs _|_ exang, restecg, sex, thalach | age, trestbps, heartdisease, chol)
# (fbs _|_ restecg | age, heartdisease, chol, thalach)
# (fbs _|_ restecg, thalach | age, sex, heartdisease, chol)
# (fbs _|_ restecg, thalach | exang, trestbps, heartdisease, chol)
# (fbs _|_ restecg | exang, heartdisease, chol, thalach)
# (fbs _|_ restecg, thalach | exang, sex, heartdisease, chol)
# (fbs _|_ restecg | trestbps, heartdisease, chol, thalach)
# (fbs _|_ restecg, thalach | sex, trestbps, heartdisease, chol)
# (fbs _|_ restecg | sex, heartdisease, chol, thalach)
# (fbs _|_ sex | age, trestbps, exang, thalach)
# (fbs _|_ chol, restecg, sex, thalach | age, trestbps, heartdisease, exang)
# (fbs _|_ restecg, chol | age, heartdisease, exang, thalach)
# (fbs _|_ restecg, chol, thalach | age, sex, heartdisease, exang)
# (fbs _|_ exang | age, trestbps, sex, thalach)
# (fbs _|_ exang, chol, restecg, sex | age, trestbps, heartdisease, thalach)
# (fbs _|_ exang, restecg, chol, thalach | age, trestbps, heartdisease, sex)
# (fbs _|_ restecg, chol | age, heartdisease, sex, thalach)
# (fbs _|_ restecg, chol | exang, trestbps, heartdisease, thalach)
# (fbs _|_ restecg, chol, thalach | exang, trestbps, heartdisease, sex)
# (fbs _|_ restecg, chol | exang, heartdisease, sex, thalach)
# (fbs _|_ restecg, chol | trestbps, heartdisease, sex, thalach)
# (fbs _|_ sex | restecg, chol, age, exang, trestbps)
# (fbs _|_ thalach | restecg, chol, age, exang, heartdisease)
# (fbs _|_ exang, sex | restecg, chol, age, trestbps, thalach)
# (fbs _|_ exang | restecg, chol, age, trestbps, sex)
# (fbs _|_ exang, sex, thalach | restecg, chol, age, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, chol, age, sex, heartdisease)
# (fbs _|_ thalach | restecg, chol, exang, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, chol, exang, sex, heartdisease)
# (fbs _|_ thalach | restecg, chol, trestbps, sex, heartdisease)
# (fbs _|_ sex | restecg, age, exang, trestbps, thalach)
# (fbs _|_ chol, sex, thalach | restecg, age, exang, trestbps, heartdisease)
# (fbs _|_ chol | restecg, age, exang, thalach, heartdisease)
# (fbs _|_ chol, thalach | restecg, age, exang, sex, heartdisease)
# (fbs _|_ exang | restecg, age, trestbps, thalach, sex)
# (fbs _|_ exang, chol, sex | restecg, age, trestbps, thalach, heartdisease)
# (fbs _|_ exang, chol, thalach | restecg, age, trestbps, sex, heartdisease)
# (fbs _|_ chol | restecg, age, thalach, sex, heartdisease)
# (fbs _|_ chol | restecg, exang, trestbps, thalach, heartdisease)
# (fbs _|_ chol, thalach | restecg, exang, trestbps, sex, heartdisease)
# (fbs _|_ chol | restecg, exang, thalach, sex, heartdisease)
# (fbs _|_ chol | restecg, trestbps, thalach, sex, heartdisease)
# (fbs _|_ sex | chol, age, exang, trestbps, thalach)
# (fbs _|_ restecg, sex, thalach | chol, age, exang, trestbps, heartdisease)
# (fbs _|_ restecg | chol, age, exang, thalach, heartdisease)
# (fbs _|_ restecg, thalach | chol, age, exang, sex, heartdisease)
# (fbs _|_ exang | chol, age, trestbps, thalach, sex)
# (fbs _|_ exang, restecg, sex | chol, age, trestbps, thalach, heartdisease)
# (fbs _|_ exang, restecg, thalach | chol, age, trestbps, sex, heartdisease)
# (fbs _|_ restecg | chol, age, thalach, sex, heartdisease)
# (fbs _|_ restecg | chol, exang, trestbps, thalach, heartdisease)
# (fbs _|_ restecg, thalach | chol, exang, trestbps, sex, heartdisease)
# (fbs _|_ restecg | chol, exang, thalach, sex, heartdisease)
# (fbs _|_ restecg | chol, trestbps, thalach, sex, heartdisease)
# (fbs _|_ chol, restecg, sex | age, exang, trestbps, thalach, heartdisease)
# (fbs _|_ restecg, chol, thalach | age, exang, trestbps, sex, heartdisease)
# (fbs _|_ restecg, chol | age, exang, thalach, sex, heartdisease)
# (fbs _|_ exang, restecg, chol | age, trestbps, thalach, sex, heartdisease)
# (fbs _|_ restecg, chol | exang, trestbps, thalach, sex, heartdisease)
# (fbs _|_ sex | restecg, chol, age, exang, trestbps, thalach)
# (fbs _|_ sex, thalach | restecg, chol, age, exang, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, chol, age, exang, sex, heartdisease)
# (fbs _|_ exang | restecg, chol, age, trestbps, thalach, sex)
# (fbs _|_ exang, sex | restecg, chol, age, trestbps, thalach, heartdisease)
# (fbs _|_ exang, thalach | restecg, chol, age, trestbps, sex, heartdisease)
# (fbs _|_ thalach | restecg, chol, exang, trestbps, sex, heartdisease)
# (fbs _|_ chol, sex | restecg, age, exang, trestbps, thalach, heartdisease)
# (fbs _|_ chol, thalach | restecg, age, exang, trestbps, sex, heartdisease)
# (fbs _|_ chol | restecg, age, exang, thalach, sex, heartdisease)
# (fbs _|_ exang, chol | restecg, age, trestbps, thalach, sex, heartdisease)
# (fbs _|_ chol | restecg, exang, trestbps, thalach, sex, heartdisease)
# (fbs _|_ restecg, sex | chol, age, exang, trestbps, thalach, heartdisease)
# (fbs _|_ restecg, thalach | chol, age, exang, trestbps, sex, heartdisease)
# (fbs _|_ restecg | chol, age, exang, thalach, sex, heartdisease)
# (fbs _|_ exang, restecg | chol, age, trestbps, thalach, sex, heartdisease)
# (fbs _|_ restecg | chol, exang, trestbps, thalach, sex, heartdisease)
# (fbs _|_ restecg, chol | age, exang, trestbps, thalach, sex, heartdisease)
# (fbs _|_ sex | restecg, chol, age, exang, trestbps, thalach, heartdisease)
# (fbs _|_ thalach | restecg, chol, age, exang, trestbps, sex, heartdisease)
# (fbs _|_ exang | restecg, chol, age, trestbps, thalach, sex, heartdisease)
# (fbs _|_ chol | restecg, age, exang, trestbps, thalach, sex, heartdisease)
# (fbs _|_ restecg | chol, age, exang, trestbps, thalach, sex, heartdisease)
# (sex _|_ age, exang, fbs)
# (sex _|_ exang, fbs | age)
# (sex _|_ age, fbs | exang)
# (sex _|_ age, exang | fbs)
# (sex _|_ restecg, chol, thalach | heartdisease)
# (sex _|_ chol, thalach | heartdisease, restecg)
# (sex _|_ restecg, thalach | heartdisease, chol)
# (sex _|_ fbs | age, exang)
# (sex _|_ restecg, chol, fbs, heartdisease, thalach | age, trestbps)
# (sex _|_ exang | age, fbs)
# (sex _|_ restecg, chol, thalach | age, heartdisease)
# (sex _|_ age | exang, fbs)
# (sex _|_ restecg, chol, thalach | exang, heartdisease)
# (sex _|_ heartdisease, restecg, chol, thalach | trestbps, fbs)
# (sex _|_ restecg, chol, thalach | trestbps, heartdisease)
# (sex _|_ restecg, chol | heartdisease, thalach)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs)
# (sex _|_ thalach | heartdisease, restecg, chol)
# (sex _|_ heartdisease, chol, fbs, thalach | age, trestbps, restecg)
# (sex _|_ chol, thalach | age, heartdisease, restecg)
# (sex _|_ chol, thalach | exang, heartdisease, restecg)
# (sex _|_ heartdisease, chol, thalach | trestbps, restecg, fbs)
# (sex _|_ chol, thalach | heartdisease, trestbps, restecg)
# (sex _|_ chol | heartdisease, restecg, thalach)
# (sex _|_ chol, thalach | heartdisease, restecg, fbs)
# (sex _|_ heartdisease, restecg, fbs, thalach | age, trestbps, chol)
# (sex _|_ restecg, thalach | age, heartdisease, chol)
# (sex _|_ restecg, thalach | exang, heartdisease, chol)
# (sex _|_ heartdisease, restecg, thalach | trestbps, chol, fbs)
# (sex _|_ restecg, thalach | trestbps, heartdisease, chol)
# (sex _|_ restecg | heartdisease, chol, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol, fbs)
# (sex _|_ restecg, chol, fbs, heartdisease, thalach | age, trestbps, exang)
# (sex _|_ restecg, chol, thalach | age, heartdisease, exang)
# (sex _|_ heartdisease, restecg, chol, fbs | age, trestbps, thalach)
# (sex _|_ heartdisease, restecg, chol, thalach | age, trestbps, fbs)
# (sex _|_ restecg, chol, fbs, thalach | age, trestbps, heartdisease)
# (sex _|_ restecg, chol | age, heartdisease, thalach)
# (sex _|_ restecg, chol, thalach | age, heartdisease, fbs)
# (sex _|_ heartdisease, restecg, chol, thalach | exang, trestbps, fbs)
# (sex _|_ restecg, chol, thalach | exang, trestbps, heartdisease)
# (sex _|_ restecg, chol | exang, heartdisease, thalach)
# (sex _|_ restecg, chol, thalach | exang, heartdisease, fbs)
# (sex _|_ heartdisease, restecg, chol | trestbps, fbs, thalach)
# (sex _|_ restecg, chol | trestbps, heartdisease, thalach)
# (sex _|_ restecg, chol, thalach | trestbps, heartdisease, fbs)
# (sex _|_ restecg, chol | heartdisease, fbs, thalach)
# (sex _|_ heartdisease, fbs, thalach | age, trestbps, restecg, chol)
# (sex _|_ thalach | age, heartdisease, restecg, chol)
# (sex _|_ thalach | exang, heartdisease, restecg, chol)
# (sex _|_ heartdisease, thalach | trestbps, restecg, chol, fbs)
# (sex _|_ thalach | heartdisease, trestbps, restecg, chol)
# (sex _|_ thalach | heartdisease, restecg, chol, fbs)
# (sex _|_ heartdisease, chol, fbs, thalach | age, trestbps, restecg, exang)
# (sex _|_ chol, thalach | age, heartdisease, restecg, exang)
# (sex _|_ heartdisease, chol, fbs | age, trestbps, restecg, thalach)
# (sex _|_ heartdisease, chol, thalach | age, trestbps, restecg, fbs)
# (sex _|_ chol, fbs, thalach | age, heartdisease, trestbps, restecg)
# (sex _|_ chol | age, heartdisease, restecg, thalach)
# (sex _|_ chol, thalach | age, heartdisease, restecg, fbs)
# (sex _|_ heartdisease, chol, thalach | exang, trestbps, restecg, fbs)
# (sex _|_ chol, thalach | exang, heartdisease, trestbps, restecg)
# (sex _|_ chol | exang, heartdisease, restecg, thalach)
# (sex _|_ chol, thalach | exang, heartdisease, restecg, fbs)
# (sex _|_ heartdisease, chol | trestbps, restecg, fbs, thalach)
# (sex _|_ chol | heartdisease, trestbps, restecg, thalach)
# (sex _|_ chol, thalach | heartdisease, trestbps, restecg, fbs)
# (sex _|_ chol | heartdisease, restecg, fbs, thalach)
# (sex _|_ restecg, heartdisease, fbs, thalach | age, exang, chol, trestbps)
# (sex _|_ restecg, thalach | age, exang, heartdisease, chol)
# (sex _|_ restecg, heartdisease, fbs | age, trestbps, chol, thalach)
# (sex _|_ restecg, heartdisease, thalach | age, trestbps, chol, fbs)
# (sex _|_ restecg, fbs, thalach | age, trestbps, heartdisease, chol)
# (sex _|_ restecg | age, heartdisease, chol, thalach)
# (sex _|_ restecg, thalach | age, heartdisease, chol, fbs)
# (sex _|_ restecg, heartdisease, thalach | exang, trestbps, chol, fbs)
# (sex _|_ restecg, thalach | exang, trestbps, heartdisease, chol)
# (sex _|_ restecg | exang, heartdisease, chol, thalach)
# (sex _|_ restecg, thalach | exang, heartdisease, chol, fbs)
# (sex _|_ restecg, heartdisease | trestbps, chol, fbs, thalach)
# (sex _|_ restecg | trestbps, heartdisease, chol, thalach)
# (sex _|_ restecg, thalach | trestbps, heartdisease, chol, fbs)
# (sex _|_ restecg | heartdisease, chol, fbs, thalach)
# (sex _|_ restecg, heartdisease, chol, fbs | age, trestbps, exang, thalach)
# (sex _|_ restecg, heartdisease, chol, thalach | age, trestbps, exang, fbs)
# (sex _|_ restecg, chol, fbs, thalach | age, trestbps, heartdisease, exang)
# (sex _|_ restecg, chol | age, heartdisease, exang, thalach)
# (sex _|_ restecg, chol, thalach | age, heartdisease, exang, fbs)
# (sex _|_ restecg, heartdisease, chol | age, trestbps, fbs, thalach)
# (sex _|_ restecg, chol, fbs | age, trestbps, heartdisease, thalach)
# (sex _|_ restecg, chol, thalach | age, trestbps, heartdisease, fbs)
# (sex _|_ restecg, chol | age, heartdisease, fbs, thalach)
# (sex _|_ restecg, heartdisease, chol | exang, trestbps, fbs, thalach)
# (sex _|_ restecg, chol | exang, trestbps, heartdisease, thalach)
# (sex _|_ restecg, chol, thalach | exang, trestbps, heartdisease, fbs)
# (sex _|_ restecg, chol | exang, heartdisease, fbs, thalach)
# (sex _|_ restecg, chol | trestbps, heartdisease, fbs, thalach)
# (sex _|_ heartdisease, fbs, thalach | restecg, chol, age, exang, trestbps)
# (sex _|_ thalach | restecg, chol, age, exang, heartdisease)
# (sex _|_ heartdisease, fbs | restecg, chol, age, trestbps, thalach)
# (sex _|_ heartdisease, thalach | restecg, chol, age, trestbps, fbs)
# (sex _|_ fbs, thalach | restecg, chol, age, trestbps, heartdisease)
# (sex _|_ thalach | restecg, chol, age, fbs, heartdisease)
# (sex _|_ heartdisease, thalach | restecg, chol, exang, trestbps, fbs)
# (sex _|_ thalach | restecg, chol, exang, trestbps, heartdisease)
# (sex _|_ thalach | restecg, chol, exang, fbs, heartdisease)
# (sex _|_ heartdisease | restecg, chol, trestbps, thalach, fbs)
# (sex _|_ thalach | restecg, chol, trestbps, fbs, heartdisease)
# (sex _|_ heartdisease, chol, fbs | restecg, age, exang, trestbps, thalach)
# (sex _|_ heartdisease, chol, thalach | restecg, age, exang, trestbps, fbs)
# (sex _|_ chol, fbs, thalach | restecg, age, exang, trestbps, heartdisease)
# (sex _|_ chol | restecg, age, exang, thalach, heartdisease)
# (sex _|_ chol, thalach | restecg, age, exang, fbs, heartdisease)
# (sex _|_ heartdisease, chol | restecg, age, trestbps, thalach, fbs)
# (sex _|_ chol, fbs | restecg, age, trestbps, thalach, heartdisease)
# (sex _|_ chol, thalach | restecg, age, trestbps, fbs, heartdisease)
# (sex _|_ chol | restecg, age, thalach, fbs, heartdisease)
# (sex _|_ heartdisease, chol | restecg, exang, trestbps, thalach, fbs)
# (sex _|_ chol | restecg, exang, trestbps, thalach, heartdisease)
# (sex _|_ chol, thalach | restecg, exang, trestbps, fbs, heartdisease)
# (sex _|_ chol | restecg, exang, thalach, fbs, heartdisease)
# (sex _|_ chol | restecg, trestbps, thalach, fbs, heartdisease)
# (sex _|_ restecg, heartdisease, fbs | chol, age, exang, trestbps, thalach)
# (sex _|_ restecg, heartdisease, thalach | chol, age, exang, trestbps, fbs)
# (sex _|_ restecg, fbs, thalach | chol, age, exang, trestbps, heartdisease)
# (sex _|_ restecg | chol, age, exang, thalach, heartdisease)
# (sex _|_ restecg, thalach | chol, age, exang, fbs, heartdisease)
# (sex _|_ restecg, heartdisease | chol, age, trestbps, thalach, fbs)
# (sex _|_ restecg, fbs | chol, age, trestbps, thalach, heartdisease)
# (sex _|_ restecg, thalach | chol, age, trestbps, fbs, heartdisease)
# (sex _|_ restecg | chol, age, thalach, fbs, heartdisease)
# (sex _|_ restecg, heartdisease | chol, exang, trestbps, thalach, fbs)
# (sex _|_ restecg | chol, exang, trestbps, thalach, heartdisease)
# (sex _|_ restecg, thalach | chol, exang, trestbps, fbs, heartdisease)
# (sex _|_ restecg | chol, exang, thalach, fbs, heartdisease)
# (sex _|_ restecg | chol, trestbps, thalach, fbs, heartdisease)
# (sex _|_ restecg, heartdisease, chol | age, exang, trestbps, thalach, fbs)
# (sex _|_ restecg, chol, fbs | age, exang, trestbps, thalach, heartdisease)
# (sex _|_ restecg, chol, thalach | age, exang, trestbps, fbs, heartdisease)
# (sex _|_ restecg, chol | age, exang, thalach, fbs, heartdisease)
# (sex _|_ restecg, chol | age, trestbps, thalach, fbs, heartdisease)
# (sex _|_ restecg, chol | exang, trestbps, thalach, fbs, heartdisease)
# (sex _|_ heartdisease, fbs | restecg, chol, age, exang, trestbps, thalach)
# (sex _|_ heartdisease, thalach | restecg, chol, age, exang, trestbps, fbs)
# (sex _|_ fbs, thalach | restecg, chol, age, exang, trestbps, heartdisease)
# (sex _|_ thalach | restecg, chol, age, exang, fbs, heartdisease)
# (sex _|_ heartdisease | restecg, chol, age, trestbps, thalach, fbs)
# (sex _|_ fbs | restecg, chol, age, trestbps, thalach, heartdisease)
# (sex _|_ thalach | restecg, chol, age, trestbps, fbs, heartdisease)
# (sex _|_ heartdisease | restecg, chol, exang, trestbps, thalach, fbs)
# (sex _|_ thalach | restecg, chol, exang, trestbps, fbs, heartdisease)
# (sex _|_ heartdisease, chol | restecg, age, exang, trestbps, thalach, fbs)
# (sex _|_ chol, fbs | restecg, age, exang, trestbps, thalach, heartdisease)
# (sex _|_ chol, thalach | restecg, age, exang, trestbps, fbs, heartdisease)
# (sex _|_ chol | restecg, age, exang, thalach, fbs, heartdisease)
# (sex _|_ chol | restecg, age, trestbps, thalach, fbs, heartdisease)
# (sex _|_ chol | restecg, exang, trestbps, thalach, fbs, heartdisease)
# (sex _|_ restecg, heartdisease | chol, age, exang, trestbps, thalach, fbs)
# (sex _|_ restecg, fbs | chol, age, exang, trestbps, thalach, heartdisease)
# (sex _|_ restecg, thalach | chol, age, exang, trestbps, fbs, heartdisease)
# (sex _|_ restecg | chol, age, exang, thalach, fbs, heartdisease)
# (sex _|_ restecg | chol, age, trestbps, thalach, fbs, heartdisease)
# (sex _|_ restecg | chol, exang, trestbps, thalach, fbs, heartdisease)
# (sex _|_ restecg, chol | age, exang, trestbps, thalach, fbs, heartdisease)
# (sex _|_ heartdisease | restecg, chol, age, exang, trestbps, thalach, fbs)
# (sex _|_ fbs | restecg, chol, age, exang, trestbps, thalach, heartdisease)
# (sex _|_ thalach | restecg, chol, age, exang, trestbps, fbs, heartdisease)
# (sex _|_ chol | restecg, age, exang, trestbps, thalach, fbs, heartdisease)
# (sex _|_ restecg | chol, age, exang, trestbps, thalach, fbs, heartdisease)
# (exang _|_ age, sex, fbs)
# (exang _|_ sex, fbs | age)
# (exang _|_ age, fbs | sex)
# (exang _|_ age, sex | fbs)
# (exang _|_ restecg, chol, thalach | heartdisease)
# (exang _|_ chol, thalach | heartdisease, restecg)
# (exang _|_ restecg, thalach | heartdisease, chol)
# (exang _|_ restecg, chol, fbs, heartdisease, thalach | age, trestbps)
# (exang _|_ fbs | age, sex)
# (exang _|_ sex | age, fbs)
# (exang _|_ restecg, chol, thalach | age, heartdisease)
# (exang _|_ heartdisease, restecg, chol, thalach | trestbps, fbs)
# (exang _|_ restecg, chol, thalach | trestbps, heartdisease)
# (exang _|_ restecg, chol | heartdisease, thalach)
# (exang _|_ age | sex, fbs)
# (exang _|_ restecg, chol, thalach | heartdisease, sex)
# (exang _|_ restecg, chol, thalach | heartdisease, fbs)
# (exang _|_ thalach | heartdisease, restecg, chol)
# (exang _|_ heartdisease, chol, fbs, thalach | age, trestbps, restecg)
# (exang _|_ chol, thalach | age, heartdisease, restecg)
# (exang _|_ heartdisease, chol, thalach | trestbps, restecg, fbs)
# (exang _|_ chol, thalach | heartdisease, trestbps, restecg)
# (exang _|_ chol | heartdisease, restecg, thalach)
# (exang _|_ chol, thalach | heartdisease, restecg, sex)
# (exang _|_ chol, thalach | heartdisease, restecg, fbs)
# (exang _|_ heartdisease, restecg, fbs, thalach | age, trestbps, chol)
# (exang _|_ restecg, thalach | age, heartdisease, chol)
# (exang _|_ heartdisease, restecg, thalach | trestbps, chol, fbs)
# (exang _|_ restecg, thalach | trestbps, heartdisease, chol)
# (exang _|_ restecg | heartdisease, chol, thalach)
# (exang _|_ restecg, thalach | sex, heartdisease, chol)
# (exang _|_ restecg, thalach | heartdisease, chol, fbs)
# (exang _|_ heartdisease, restecg, chol, fbs | age, trestbps, thalach)
# (exang _|_ restecg, chol, fbs, heartdisease, thalach | age, trestbps, sex)
# (exang _|_ heartdisease, restecg, chol, thalach | age, trestbps, fbs)
# (exang _|_ restecg, chol, fbs, thalach | age, trestbps, heartdisease)
# (exang _|_ restecg, chol | age, heartdisease, thalach)
# (exang _|_ restecg, chol, thalach | age, heartdisease, sex)
# (exang _|_ restecg, chol, thalach | age, heartdisease, fbs)
# (exang _|_ heartdisease, restecg, chol | trestbps, fbs, thalach)
# (exang _|_ restecg, chol | trestbps, heartdisease, thalach)
# (exang _|_ heartdisease, restecg, chol, thalach | trestbps, sex, fbs)
# (exang _|_ restecg, chol, thalach | trestbps, heartdisease, sex)
# (exang _|_ restecg, chol, thalach | trestbps, heartdisease, fbs)
# (exang _|_ restecg, chol | heartdisease, sex, thalach)
# (exang _|_ restecg, chol | heartdisease, fbs, thalach)
# (exang _|_ restecg, chol, thalach | heartdisease, sex, fbs)
# (exang _|_ heartdisease, fbs, thalach | age, trestbps, restecg, chol)
# (exang _|_ thalach | age, heartdisease, restecg, chol)
# (exang _|_ heartdisease, thalach | trestbps, restecg, chol, fbs)
# (exang _|_ thalach | heartdisease, trestbps, restecg, chol)
# (exang _|_ thalach | sex, restecg, chol, heartdisease)
# (exang _|_ thalach | heartdisease, restecg, chol, fbs)
# (exang _|_ heartdisease, chol, fbs | age, trestbps, restecg, thalach)
# (exang _|_ heartdisease, chol, fbs, thalach | age, trestbps, restecg, sex)
# (exang _|_ heartdisease, chol, thalach | age, trestbps, restecg, fbs)
# (exang _|_ chol, fbs, thalach | age, heartdisease, trestbps, restecg)
# (exang _|_ chol | age, heartdisease, restecg, thalach)
# (exang _|_ chol, thalach | age, heartdisease, restecg, sex)
# (exang _|_ chol, thalach | age, heartdisease, restecg, fbs)
# (exang _|_ heartdisease, chol | trestbps, restecg, fbs, thalach)
# (exang _|_ chol | heartdisease, trestbps, restecg, thalach)
# (exang _|_ heartdisease, chol, thalach | trestbps, restecg, sex, fbs)
# (exang _|_ chol, thalach | heartdisease, trestbps, restecg, sex)
# (exang _|_ chol, thalach | heartdisease, trestbps, restecg, fbs)
# (exang _|_ chol | heartdisease, restecg, sex, thalach)
# (exang _|_ chol | heartdisease, restecg, fbs, thalach)
# (exang _|_ chol, thalach | heartdisease, restecg, sex, fbs)
# (exang _|_ restecg, heartdisease, fbs | age, trestbps, chol, thalach)
# (exang _|_ restecg, heartdisease, fbs, thalach | age, sex, trestbps, chol)
# (exang _|_ restecg, heartdisease, thalach | age, trestbps, chol, fbs)
# (exang _|_ restecg, fbs, thalach | age, trestbps, heartdisease, chol)
# (exang _|_ restecg | age, heartdisease, chol, thalach)
# (exang _|_ restecg, thalach | age, sex, heartdisease, chol)
# (exang _|_ restecg, thalach | age, heartdisease, chol, fbs)
# (exang _|_ restecg, heartdisease | trestbps, chol, fbs, thalach)
# (exang _|_ restecg | trestbps, heartdisease, chol, thalach)
# (exang _|_ restecg, heartdisease, thalach | sex, trestbps, chol, fbs)
# (exang _|_ restecg, thalach | sex, trestbps, heartdisease, chol)
# (exang _|_ restecg, thalach | trestbps, heartdisease, chol, fbs)
# (exang _|_ restecg | sex, heartdisease, chol, thalach)
# (exang _|_ restecg | heartdisease, chol, fbs, thalach)
# (exang _|_ restecg, thalach | sex, heartdisease, chol, fbs)
# (exang _|_ restecg, heartdisease, chol, fbs | age, trestbps, sex, thalach)
# (exang _|_ heartdisease, restecg, chol | age, trestbps, fbs, thalach)
# (exang _|_ restecg, chol, fbs | age, trestbps, heartdisease, thalach)
# (exang _|_ restecg, heartdisease, chol, thalach | age, trestbps, sex, fbs)
# (exang _|_ restecg, chol, fbs, thalach | age, trestbps, heartdisease, sex)
# (exang _|_ restecg, chol, thalach | age, trestbps, heartdisease, fbs)
# (exang _|_ restecg, chol | age, heartdisease, sex, thalach)
# (exang _|_ restecg, chol | age, heartdisease, fbs, thalach)
# (exang _|_ restecg, chol, thalach | age, heartdisease, sex, fbs)
# (exang _|_ restecg, heartdisease, chol | trestbps, sex, fbs, thalach)
# (exang _|_ restecg, chol | trestbps, heartdisease, sex, thalach)
# (exang _|_ restecg, chol | trestbps, heartdisease, fbs, thalach)
# (exang _|_ restecg, chol, thalach | trestbps, heartdisease, sex, fbs)
# (exang _|_ restecg, chol | heartdisease, sex, fbs, thalach)
# (exang _|_ heartdisease, fbs | restecg, chol, age, trestbps, thalach)
# (exang _|_ heartdisease, fbs, thalach | restecg, chol, age, trestbps, sex)
# (exang _|_ heartdisease, thalach | restecg, chol, age, trestbps, fbs)
# (exang _|_ fbs, thalach | restecg, chol, age, trestbps, heartdisease)
# (exang _|_ thalach | restecg, chol, age, sex, heartdisease)
# (exang _|_ thalach | restecg, chol, age, fbs, heartdisease)
# (exang _|_ heartdisease | restecg, chol, trestbps, thalach, fbs)
# (exang _|_ heartdisease, thalach | restecg, chol, trestbps, sex, fbs)
# (exang _|_ thalach | restecg, chol, trestbps, sex, heartdisease)
# (exang _|_ thalach | restecg, chol, trestbps, fbs, heartdisease)
# (exang _|_ thalach | restecg, chol, sex, fbs, heartdisease)
# (exang _|_ heartdisease, chol, fbs | restecg, age, trestbps, thalach, sex)
# (exang _|_ heartdisease, chol | restecg, age, trestbps, thalach, fbs)
# (exang _|_ chol, fbs | restecg, age, trestbps, thalach, heartdisease)
# (exang _|_ heartdisease, chol, thalach | restecg, age, trestbps, sex, fbs)
# (exang _|_ chol, fbs, thalach | restecg, age, trestbps, sex, heartdisease)
# (exang _|_ chol, thalach | restecg, age, trestbps, fbs, heartdisease)
# (exang _|_ chol | restecg, age, thalach, sex, heartdisease)
# (exang _|_ chol | restecg, age, thalach, fbs, heartdisease)
# (exang _|_ chol, thalach | restecg, age, sex, fbs, heartdisease)
# (exang _|_ heartdisease, chol | restecg, trestbps, thalach, sex, fbs)
# (exang _|_ chol | restecg, trestbps, thalach, sex, heartdisease)
# (exang _|_ chol | restecg, trestbps, thalach, fbs, heartdisease)
# (exang _|_ chol, thalach | restecg, trestbps, sex, fbs, heartdisease)
# (exang _|_ chol | restecg, thalach, sex, fbs, heartdisease)
# (exang _|_ restecg, heartdisease, fbs | chol, age, trestbps, thalach, sex)
# (exang _|_ restecg, heartdisease | chol, age, trestbps, thalach, fbs)
# (exang _|_ restecg, fbs | chol, age, trestbps, thalach, heartdisease)
# (exang _|_ restecg, heartdisease, thalach | chol, age, trestbps, sex, fbs)
# (exang _|_ restecg, fbs, thalach | chol, age, trestbps, sex, heartdisease)
# (exang _|_ restecg, thalach | chol, age, trestbps, fbs, heartdisease)
# (exang _|_ restecg | chol, age, thalach, sex, heartdisease)
# (exang _|_ restecg | chol, age, thalach, fbs, heartdisease)
# (exang _|_ restecg, thalach | chol, age, sex, fbs, heartdisease)
# (exang _|_ restecg, heartdisease | chol, trestbps, thalach, sex, fbs)
# (exang _|_ restecg | chol, trestbps, thalach, sex, heartdisease)
# (exang _|_ restecg | chol, trestbps, thalach, fbs, heartdisease)
# (exang _|_ restecg, thalach | chol, trestbps, sex, fbs, heartdisease)
# (exang _|_ restecg | chol, thalach, sex, fbs, heartdisease)
# (exang _|_ restecg, heartdisease, chol | age, trestbps, thalach, sex, fbs)
# (exang _|_ restecg, chol, fbs | age, trestbps, thalach, sex, heartdisease)
# (exang _|_ restecg, chol | age, trestbps, thalach, fbs, heartdisease)
# (exang _|_ restecg, chol, thalach | age, trestbps, sex, fbs, heartdisease)
# (exang _|_ restecg, chol | age, thalach, sex, fbs, heartdisease)
# (exang _|_ restecg, chol | trestbps, thalach, sex, fbs, heartdisease)
# (exang _|_ heartdisease, fbs | restecg, chol, age, trestbps, thalach, sex)
# (exang _|_ heartdisease | restecg, chol, age, trestbps, thalach, fbs)
# (exang _|_ fbs | restecg, chol, age, trestbps, thalach, heartdisease)
# (exang _|_ heartdisease, thalach | restecg, chol, age, trestbps, sex, fbs)
# (exang _|_ fbs, thalach | restecg, chol, age, trestbps, sex, heartdisease)
# (exang _|_ thalach | restecg, chol, age, trestbps, fbs, heartdisease)
# (exang _|_ thalach | restecg, chol, age, sex, fbs, heartdisease)
# (exang _|_ heartdisease | restecg, chol, trestbps, thalach, sex, fbs)
# (exang _|_ thalach | restecg, chol, trestbps, sex, fbs, heartdisease)
# (exang _|_ heartdisease, chol | restecg, age, trestbps, thalach, sex, fbs)
# (exang _|_ chol, fbs | restecg, age, trestbps, thalach, sex, heartdisease)
# (exang _|_ chol | restecg, age, trestbps, thalach, fbs, heartdisease)
# (exang _|_ chol, thalach | restecg, age, trestbps, sex, fbs, heartdisease)
# (exang _|_ chol | restecg, age, thalach, sex, fbs, heartdisease)
# (exang _|_ chol | restecg, trestbps, thalach, sex, fbs, heartdisease)
# (exang _|_ restecg, heartdisease | chol, age, trestbps, thalach, sex, fbs)
# (exang _|_ restecg, fbs | chol, age, trestbps, thalach, sex, heartdisease)
# (exang _|_ restecg | chol, age, trestbps, thalach, fbs, heartdisease)
# (exang _|_ restecg, thalach | chol, age, trestbps, sex, fbs, heartdisease)
# (exang _|_ restecg | chol, age, thalach, sex, fbs, heartdisease)
# (exang _|_ restecg | chol, trestbps, thalach, sex, fbs, heartdisease)
# (exang _|_ restecg, chol | age, trestbps, thalach, sex, fbs, heartdisease)
# (exang _|_ heartdisease | restecg, chol, age, trestbps, thalach, sex, fbs)
# (exang _|_ fbs | restecg, chol, age, trestbps, thalach, sex, heartdisease)
# (exang _|_ thalach | restecg, chol, age, trestbps, sex, fbs, heartdisease)
# (exang _|_ chol | restecg, age, trestbps, thalach, sex, fbs, heartdisease)
# (exang _|_ restecg | chol, age, trestbps, thalach, sex, fbs, heartdisease)
# (heartdisease _|_ exang, sex | age, trestbps)
# (heartdisease _|_ age, sex, exang | trestbps, fbs)
# (heartdisease _|_ exang, sex | age, trestbps, restecg)
# (heartdisease _|_ age, sex, exang | trestbps, restecg, fbs)
# (heartdisease _|_ exang, sex | age, trestbps, chol)
# (heartdisease _|_ age, sex, exang | trestbps, chol, fbs)
# (heartdisease _|_ sex | age, trestbps, exang)
# (heartdisease _|_ exang, sex | age, trestbps, thalach)
# (heartdisease _|_ exang | age, trestbps, sex)
# (heartdisease _|_ exang, sex | age, trestbps, fbs)
# (heartdisease _|_ age, sex | exang, trestbps, fbs)
# (heartdisease _|_ age, sex, exang | trestbps, fbs, thalach)
# (heartdisease _|_ age, exang | trestbps, sex, fbs)
# (heartdisease _|_ exang, sex | age, trestbps, restecg, chol)
# (heartdisease _|_ age, exang, sex | trestbps, restecg, chol, fbs)
# (heartdisease _|_ sex | age, trestbps, restecg, exang)
# (heartdisease _|_ exang, sex | age, trestbps, restecg, thalach)
# (heartdisease _|_ exang | age, trestbps, restecg, sex)
# (heartdisease _|_ exang, sex | age, trestbps, restecg, fbs)
# (heartdisease _|_ age, sex | exang, trestbps, restecg, fbs)
# (heartdisease _|_ age, exang, sex | trestbps, restecg, fbs, thalach)
# (heartdisease _|_ age, exang | trestbps, restecg, sex, fbs)
# (heartdisease _|_ sex | age, exang, chol, trestbps)
# (heartdisease _|_ exang, sex | age, trestbps, chol, thalach)
# ...
# (thalach _|_ chol, sex, fbs | restecg, age, exang, trestbps, heartdisease)
# (thalach _|_ trestbps, chol, fbs | restecg, age, exang, sex, heartdisease)
# (thalach _|_ chol, trestbps, sex | restecg, age, exang, fbs, heartdisease)
# (thalach _|_ exang | restecg, age, trestbps, sex, fbs)
# (thalach _|_ exang, chol, fbs | restecg, age, trestbps, sex, heartdisease)
# (thalach _|_ exang, chol, sex | restecg, age, trestbps, fbs, heartdisease)
# (thalach _|_ exang, trestbps, chol | restecg, age, sex, fbs, heartdisease)
# (thalach _|_ age | restecg, exang, trestbps, sex, fbs)
# (thalach _|_ age, chol, fbs | restecg, exang, trestbps, sex, heartdisease)
# (thalach _|_ age, chol, sex | restecg, exang, trestbps, fbs, heartdisease)
# (thalach _|_ age, trestbps, chol | restecg, exang, sex, fbs, heartdisease)
# (thalach _|_ age, chol, exang | restecg, trestbps, sex, fbs, heartdisease)
# (thalach _|_ sex | chol, age, exang, trestbps, fbs)
# (thalach _|_ restecg, sex, fbs | chol, age, exang, trestbps, heartdisease)
# (thalach _|_ trestbps, restecg, fbs | chol, age, exang, sex, heartdisease)
# (thalach _|_ trestbps, restecg, sex | chol, age, exang, fbs, heartdisease)
# (thalach _|_ exang | chol, age, trestbps, sex, fbs)
# (thalach _|_ exang, restecg, fbs | chol, age, trestbps, sex, heartdisease)
# (thalach _|_ exang, restecg, sex | chol, age, trestbps, fbs, heartdisease)
# (thalach _|_ exang, trestbps, restecg | chol, age, sex, fbs, heartdisease)
# (thalach _|_ age | chol, exang, trestbps, sex, fbs)
# (thalach _|_ age, restecg, fbs | chol, exang, trestbps, sex, heartdisease)
# (thalach _|_ age, restecg, sex | chol, exang, trestbps, fbs, heartdisease)
# (thalach _|_ age, trestbps, restecg | chol, exang, sex, fbs, heartdisease)
# (thalach _|_ age, restecg, exang | chol, trestbps, sex, fbs, heartdisease)
# (thalach _|_ restecg, chol, fbs | age, exang, trestbps, sex, heartdisease)
# (thalach _|_ chol, restecg, sex | age, exang, trestbps, fbs, heartdisease)
# (thalach _|_ trestbps, restecg, chol | age, exang, sex, fbs, heartdisease)
# (thalach _|_ exang, restecg, chol | age, trestbps, sex, fbs, heartdisease)
# (thalach _|_ age, restecg, chol | exang, trestbps, sex, fbs, heartdisease)
# (thalach _|_ sex | restecg, chol, age, exang, trestbps, fbs)
# (thalach _|_ sex, fbs | restecg, chol, age, exang, trestbps, heartdisease)
# (thalach _|_ trestbps, fbs | restecg, chol, age, exang, sex, heartdisease)
# (thalach _|_ trestbps, sex | restecg, chol, age, exang, fbs, heartdisease)
# (thalach _|_ exang | restecg, chol, age, trestbps, sex, fbs)
# (thalach _|_ exang, fbs | restecg, chol, age, trestbps, sex, heartdisease)
# (thalach _|_ exang, sex | restecg, chol, age, trestbps, fbs, heartdisease)
# (thalach _|_ exang, trestbps | restecg, chol, age, sex, fbs, heartdisease)
# (thalach _|_ age | restecg, chol, exang, trestbps, sex, fbs)
# (thalach _|_ age, fbs | restecg, chol, exang, trestbps, sex, heartdisease)
# (thalach _|_ age, sex | restecg, chol, exang, trestbps, fbs, heartdisease)
# (thalach _|_ age, trestbps | restecg, chol, exang, sex, fbs, heartdisease)
# (thalach _|_ age, exang | restecg, chol, trestbps, sex, fbs, heartdisease)
# (thalach _|_ chol, fbs | restecg, age, exang, trestbps, sex, heartdisease)
# (thalach _|_ chol, sex | restecg, age, exang, trestbps, fbs, heartdisease)
# (thalach _|_ trestbps, chol | restecg, age, exang, sex, fbs, heartdisease)
# (thalach _|_ exang, chol | restecg, age, trestbps, sex, fbs, heartdisease)
# (thalach _|_ age, chol | restecg, exang, trestbps, sex, fbs, heartdisease)
# (thalach _|_ restecg, fbs | chol, age, exang, trestbps, sex, heartdisease)
# (thalach _|_ restecg, sex | chol, age, exang, trestbps, fbs, heartdisease)
# (thalach _|_ trestbps, restecg | chol, age, exang, sex, fbs, heartdisease)
# (thalach _|_ exang, restecg | chol, age, trestbps, sex, fbs, heartdisease)
# (thalach _|_ age, restecg | chol, exang, trestbps, sex, fbs, heartdisease)
# (thalach _|_ restecg, chol | age, exang, trestbps, sex, fbs, heartdisease)
# (thalach _|_ fbs | restecg, chol, age, exang, trestbps, sex, heartdisease)
# (thalach _|_ sex | restecg, chol, age, exang, trestbps, fbs, heartdisease)
# (thalach _|_ trestbps | restecg, chol, age, exang, sex, fbs, heartdisease)
# (thalach _|_ exang | restecg, chol, age, trestbps, sex, fbs, heartdisease)
# (thalach _|_ age | restecg, chol, exang, trestbps, sex, fbs, heartdisease)
# (thalach _|_ chol | restecg, age, exang, trestbps, sex, fbs, heartdisease)
# (thalach _|_ restecg | chol, age, exang, trestbps, sex, fbs, heartdisease)
# (chol _|_ restecg, exang, sex, fbs, age, trestbps, thalach | heartdisease)
# (chol _|_ exang, sex, fbs, age, trestbps, thalach | heartdisease, restecg)
# (chol _|_ exang, sex | age, trestbps)
# (chol _|_ restecg, sex, fbs, exang, trestbps, thalach | age, heartdisease)
# (chol _|_ restecg, sex, fbs, age, trestbps, thalach | exang, heartdisease)
# (chol _|_ age, sex, exang | trestbps, fbs)
# (chol _|_ restecg, exang, sex, fbs, age, thalach | trestbps, heartdisease)
# (chol _|_ restecg, exang, sex, fbs, age, trestbps | heartdisease, thalach)
# (chol _|_ restecg, exang, fbs, age, trestbps, thalach | heartdisease, sex)
# (chol _|_ restecg, exang, sex, age, trestbps, thalach | heartdisease, fbs)
# (chol _|_ exang, sex | age, trestbps, restecg)
# (chol _|_ sex, fbs, exang, trestbps, thalach | age, heartdisease, restecg)
# (chol _|_ sex, fbs, age, trestbps, thalach | exang, heartdisease, restecg)
# (chol _|_ age, sex, exang | trestbps, restecg, fbs)
# (chol _|_ exang, sex, fbs, age, thalach | heartdisease, trestbps, restecg)
# (chol _|_ exang, sex, fbs, age, trestbps | heartdisease, restecg, thalach)
# (chol _|_ exang, fbs, age, trestbps, thalach | heartdisease, restecg, sex)
# (chol _|_ exang, sex, age, trestbps, thalach | heartdisease, restecg, fbs)
# (chol _|_ sex | age, trestbps, exang)
# (chol _|_ restecg, sex, fbs, trestbps, thalach | age, heartdisease, exang)
# (chol _|_ exang, sex | age, trestbps, thalach)
# (chol _|_ exang | age, trestbps, sex)
# (chol _|_ exang, sex | age, trestbps, fbs)
# (chol _|_ restecg, sex, fbs, exang, thalach | age, trestbps, heartdisease)
# (chol _|_ restecg, sex, fbs, exang, trestbps | age, heartdisease, thalach)
# (chol _|_ restecg, fbs, exang, trestbps, thalach | age, heartdisease, sex)
# (chol _|_ restecg, sex, exang, trestbps, thalach | age, heartdisease, fbs)
# (chol _|_ age, sex | exang, trestbps, fbs)
# (chol _|_ restecg, sex, fbs, age, thalach | exang, trestbps, heartdisease)
# (chol _|_ restecg, sex, fbs, age, trestbps | exang, heartdisease, thalach)
# (chol _|_ restecg, fbs, age, trestbps, thalach | exang, heartdisease, sex)
# (chol _|_ restecg, sex, age, trestbps, thalach | exang, heartdisease, fbs)
# (chol _|_ age, sex, exang | trestbps, fbs, thalach)
# (chol _|_ restecg, exang, sex, fbs, age | trestbps, heartdisease, thalach)
# (chol _|_ age, exang | trestbps, sex, fbs)
# (chol _|_ restecg, exang, fbs, age, thalach | trestbps, heartdisease, sex)
# (chol _|_ restecg, exang, sex, age, thalach | trestbps, heartdisease, fbs)
# (chol _|_ restecg, exang, fbs, age, trestbps | heartdisease, sex, thalach)
# (chol _|_ restecg, exang, sex, age, trestbps | heartdisease, fbs, thalach)
# (chol _|_ restecg, exang, age, trestbps, thalach | heartdisease, sex, fbs)
# (chol _|_ sex | age, trestbps, restecg, exang)
# (chol _|_ trestbps, sex, fbs, thalach | age, heartdisease, restecg, exang)
# (chol _|_ exang, sex | age, trestbps, restecg, thalach)
# (chol _|_ exang | age, trestbps, restecg, sex)
# (chol _|_ exang, sex | age, trestbps, restecg, fbs)
# (chol _|_ exang, sex, fbs, thalach | age, heartdisease, trestbps, restecg)
# (chol _|_ exang, trestbps, sex, fbs | age, heartdisease, restecg, thalach)
# (chol _|_ exang, trestbps, fbs, thalach | age, heartdisease, restecg, sex)
# (chol _|_ exang, trestbps, sex, thalach | age, heartdisease, restecg, fbs)
# (chol _|_ age, sex | exang, trestbps, restecg, fbs)
# (chol _|_ age, sex, fbs, thalach | exang, heartdisease, trestbps, restecg)
# (chol _|_ age, trestbps, sex, fbs | exang, heartdisease, restecg, thalach)
# (chol _|_ age, trestbps, fbs, thalach | exang, heartdisease, restecg, sex)
# (chol _|_ age, trestbps, sex, thalach | exang, heartdisease, restecg, fbs)
# (chol _|_ age, exang, sex | trestbps, restecg, fbs, thalach)
# (chol _|_ age, exang, sex, fbs | heartdisease, trestbps, restecg, thalach)
# (chol _|_ age, exang | trestbps, restecg, sex, fbs)
# (chol _|_ age, exang, fbs, thalach | heartdisease, trestbps, restecg, sex)
# (chol _|_ age, exang, sex, thalach | heartdisease, trestbps, restecg, fbs)
# (chol _|_ age, trestbps, exang, fbs | heartdisease, restecg, sex, thalach)
# (chol _|_ age, trestbps, sex, exang | heartdisease, restecg, fbs, thalach)
# (chol _|_ age, trestbps, exang, thalach | heartdisease, restecg, sex, fbs)
# (chol _|_ sex | age, trestbps, exang, thalach)
# (chol _|_ sex | age, trestbps, exang, fbs)
# (chol _|_ restecg, sex, fbs, thalach | age, trestbps, heartdisease, exang)
# (chol _|_ trestbps, restecg, sex, fbs | age, heartdisease, exang, thalach)
# (chol _|_ trestbps, restecg, fbs, thalach | age, sex, heartdisease, exang)
# (chol _|_ trestbps, restecg, sex, thalach | age, heartdisease, exang, fbs)
# (chol _|_ exang | age, trestbps, sex, thalach)
# (chol _|_ exang, sex | age, trestbps, fbs, thalach)
# (chol _|_ exang, restecg, sex, fbs | age, trestbps, heartdisease, thalach)
# (chol _|_ exang | age, trestbps, sex, fbs)
# (chol _|_ exang, restecg, fbs, thalach | age, trestbps, heartdisease, sex)
# (chol _|_ exang, restecg, sex, thalach | age, trestbps, heartdisease, fbs)
# (chol _|_ exang, trestbps, restecg, fbs | age, heartdisease, sex, thalach)
# (chol _|_ exang, trestbps, restecg, sex | age, heartdisease, fbs, thalach)
# (chol _|_ exang, trestbps, restecg, thalach | age, heartdisease, sex, fbs)
# (chol _|_ age, sex | exang, trestbps, fbs, thalach)
# (chol _|_ age, restecg, sex, fbs | exang, trestbps, heartdisease, thalach)
# (chol _|_ age | exang, trestbps, sex, fbs)
# (chol _|_ age, restecg, fbs, thalach | exang, trestbps, heartdisease, sex)
# (chol _|_ age, restecg, sex, thalach | exang, trestbps, heartdisease, fbs)
# (chol _|_ age, trestbps, restecg, fbs | exang, heartdisease, sex, thalach)
# (chol _|_ age, trestbps, restecg, sex | exang, heartdisease, fbs, thalach)
# (chol _|_ age, trestbps, restecg, thalach | exang, heartdisease, sex, fbs)
# (chol _|_ age, exang | trestbps, sex, fbs, thalach)
# (chol _|_ age, restecg, exang, fbs | trestbps, heartdisease, sex, thalach)
# (chol _|_ age, exang, restecg, sex | trestbps, heartdisease, fbs, thalach)
# (chol _|_ age, restecg, exang, thalach | trestbps, heartdisease, sex, fbs)
# (chol _|_ age, trestbps, restecg, exang | heartdisease, sex, fbs, thalach)
# (chol _|_ sex | restecg, age, exang, trestbps, thalach)
# (chol _|_ sex | restecg, age, exang, trestbps, fbs)
# (chol _|_ sex, fbs, thalach | restecg, age, exang, trestbps, heartdisease)
# (chol _|_ trestbps, sex, fbs | restecg, age, exang, thalach, heartdisease)
# (chol _|_ trestbps, fbs, thalach | restecg, age, exang, sex, heartdisease)
# (chol _|_ trestbps, sex, thalach | restecg, age, exang, fbs, heartdisease)
# (chol _|_ exang | restecg, age, trestbps, thalach, sex)
# (chol _|_ exang, sex | restecg, age, trestbps, thalach, fbs)
# (chol _|_ exang, sex, fbs | restecg, age, trestbps, thalach, heartdisease)
# (chol _|_ exang | restecg, age, trestbps, sex, fbs)
# (chol _|_ exang, fbs, thalach | restecg, age, trestbps, sex, heartdisease)
# (chol _|_ exang, sex, thalach | restecg, age, trestbps, fbs, heartdisease)
# (chol _|_ exang, trestbps, fbs | restecg, age, thalach, sex, heartdisease)
# (chol _|_ exang, trestbps, sex | restecg, age, thalach, fbs, heartdisease)
# (chol _|_ exang, trestbps, thalach | restecg, age, sex, fbs, heartdisease)
# (chol _|_ age, sex | restecg, exang, trestbps, thalach, fbs)
# (chol _|_ age, sex, fbs | restecg, exang, trestbps, thalach, heartdisease)
# (chol _|_ age | restecg, exang, trestbps, sex, fbs)
# (chol _|_ age, fbs, thalach | restecg, exang, trestbps, sex, heartdisease)
# (chol _|_ age, sex, thalach | restecg, exang, trestbps, fbs, heartdisease)
# (chol _|_ age, trestbps, fbs | restecg, exang, thalach, sex, heartdisease)
# (chol _|_ age, trestbps, sex | restecg, exang, thalach, fbs, heartdisease)
# (chol _|_ age, trestbps, thalach | restecg, exang, sex, fbs, heartdisease)
# (chol _|_ age, exang | restecg, trestbps, thalach, sex, fbs)
# (chol _|_ age, exang, fbs | restecg, trestbps, thalach, sex, heartdisease)
# (chol _|_ age, exang, sex | restecg, trestbps, thalach, fbs, heartdisease)
# (chol _|_ age, exang, thalach | restecg, trestbps, sex, fbs, heartdisease)
# (chol _|_ age, trestbps, exang | restecg, thalach, sex, fbs, heartdisease)
# (chol _|_ sex | age, exang, trestbps, thalach, fbs)
# (chol _|_ restecg, sex, fbs | age, exang, trestbps, thalach, heartdisease)
# (chol _|_ restecg, fbs, thalach | age, exang, trestbps, sex, heartdisease)
# (chol _|_ restecg, sex, thalach | age, exang, trestbps, fbs, heartdisease)
# (chol _|_ trestbps, restecg, fbs | age, exang, thalach, sex, heartdisease)
# (chol _|_ trestbps, restecg, sex | age, exang, thalach, fbs, heartdisease)
# (chol _|_ trestbps, restecg, thalach | age, exang, sex, fbs, heartdisease)
# (chol _|_ exang | age, trestbps, thalach, sex, fbs)
# (chol _|_ exang, restecg, fbs | age, trestbps, thalach, sex, heartdisease)
# (chol _|_ exang, restecg, sex | age, trestbps, thalach, fbs, heartdisease)
# (chol _|_ exang, restecg, thalach | age, trestbps, sex, fbs, heartdisease)
# (chol _|_ exang, trestbps, restecg | age, thalach, sex, fbs, heartdisease)
# (chol _|_ age | exang, trestbps, thalach, sex, fbs)
# (chol _|_ age, restecg, fbs | exang, trestbps, thalach, sex, heartdisease)
# (chol _|_ age, restecg, sex | exang, trestbps, thalach, fbs, heartdisease)
# (chol _|_ age, restecg, thalach | exang, trestbps, sex, fbs, heartdisease)
# (chol _|_ age, trestbps, restecg | exang, thalach, sex, fbs, heartdisease)
# (chol _|_ age, restecg, exang | trestbps, thalach, sex, fbs, heartdisease)
# (chol _|_ sex | restecg, age, exang, trestbps, thalach, fbs)
# (chol _|_ sex, fbs | restecg, age, exang, trestbps, thalach, heartdisease)
# (chol _|_ fbs, thalach | restecg, age, exang, trestbps, sex, heartdisease)
# (chol _|_ sex, thalach | restecg, age, exang, trestbps, fbs, heartdisease)
# (chol _|_ trestbps, fbs | restecg, age, exang, thalach, sex, heartdisease)
# (chol _|_ trestbps, sex | restecg, age, exang, thalach, fbs, heartdisease)
# (chol _|_ trestbps, thalach | restecg, age, exang, sex, fbs, heartdisease)
# (chol _|_ exang | restecg, age, trestbps, thalach, sex, fbs)
# (chol _|_ exang, fbs | restecg, age, trestbps, thalach, sex, heartdisease)
# (chol _|_ exang, sex | restecg, age, trestbps, thalach, fbs, heartdisease)
# (chol _|_ exang, thalach | restecg, age, trestbps, sex, fbs, heartdisease)
# (chol _|_ exang, trestbps | restecg, age, thalach, sex, fbs, heartdisease)
# (chol _|_ age | restecg, exang, trestbps, thalach, sex, fbs)
# (chol _|_ age, fbs | restecg, exang, trestbps, thalach, sex, heartdisease)
# (chol _|_ age, sex | restecg, exang, trestbps, thalach, fbs, heartdisease)
# (chol _|_ age, thalach | restecg, exang, trestbps, sex, fbs, heartdisease)
# (chol _|_ age, trestbps | restecg, exang, thalach, sex, fbs, heartdisease)
# (chol _|_ age, exang | restecg, trestbps, thalach, sex, fbs, heartdisease)
# (chol _|_ restecg, fbs | age, exang, trestbps, thalach, sex, heartdisease)
# (chol _|_ restecg, sex | age, exang, trestbps, thalach, fbs, heartdisease)
# (chol _|_ restecg, thalach | age, exang, trestbps, sex, fbs, heartdisease)
# (chol _|_ trestbps, restecg | age, exang, thalach, sex, fbs, heartdisease)
# (chol _|_ exang, restecg | age, trestbps, thalach, sex, fbs, heartdisease)
# (chol _|_ age, restecg | exang, trestbps, thalach, sex, fbs, heartdisease)
# (chol _|_ fbs | restecg, age, exang, trestbps, thalach, sex, heartdisease)
# (chol _|_ sex | restecg, age, exang, trestbps, thalach, fbs, heartdisease)
# (chol _|_ thalach | restecg, age, exang, trestbps, sex, fbs, heartdisease)
# (chol _|_ trestbps | restecg, age, exang, thalach, sex, fbs, heartdisease)
# (chol _|_ exang | restecg, age, trestbps, thalach, sex, fbs, heartdisease)
# (chol _|_ age | restecg, exang, trestbps, thalach, sex, fbs, heartdisease)
# (chol _|_ restecg | age, exang, trestbps, thalach, sex, fbs, heartdisease)

# %%
from pgmpy.inference import VariableElimination

# %%
heartDisease_infer = VariableElimination(model)

# %%
q = heartDisease_infer.query(variables=["heartdisease"],
                             evidence={"age": 29})
print(q)
# Out:
# Finding Elimination Order: : 100%|██████████| 7/7 [00:00<00:00, 4119.56it/s]
# Eliminating: thalach: 100%|██████████| 7/7 [00:00<00:00, 756.84it/s]
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.6630 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.3370 |
# +-----------------+---------------------+

# %%
q = heartDisease_infer.query(variables=["heartdisease"],
                             evidence={"chol": 100})
print(q)
# Out:
# /Users/saiteja/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:439: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
# Finding Elimination Order: : 100%|██████████| 7/7 [00:00<00:00, 3956.89it/s]
# Eliminating: thalach: 100%|██████████| 7/7 [00:00<00:00, 404.16it/s]
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              1.0000 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.0000 |
# +-----------------+---------------------+
